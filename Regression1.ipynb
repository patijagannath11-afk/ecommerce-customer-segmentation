# %%
 # !pip install scikit-learn

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

df = pd.read_csv("student_marks1.csv")

plt.xlabel("Attendance_Percentage")
plt.ylabel("Marks_Percentage(60)")
plt.scatter(df.Attendance_Percentage, df.Marks_Percentage)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
warnings.filterwarnings("ignore")

df = pandas.read_csv("student_marks1.csv")

X = df[['weight' , 'volume']]
Y = df['CO2']

multi_regr = linear_model.linearRegression()
multi_regr.fit(X,Y)

polution = multi_regr.predict([[2300,1300]])

print(population)
print(multi_regr.coef_)
print(multi_regr.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 import matplotlib.pyplot as plt
#       4 from sklearn import linear_model
# ----> 5 warnings.filterwarnings("ignore")
#       7 df = pandas.read_csv("student_marks1.csv")
#       9 X = df[['weight' , 'volume']]
#
# NameError: name 'warnings' is not defined

# %%
import numpy as np
from sklearn import metrics 

X_train , X_test , y_train, y_test = train_test_split(X,y , test_size=0.5 , random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"%(X_test.shape[0] , (y_test!= y_pred).sum()))
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
con = confusion_matrix(y_test , y_pred)
con

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("student_marks1.csv")
plt.scatter(df.Attendance_Percentage, df.Marks_Percentage)

# %%
km = KMeans(n_clusters = 3 )
km
# Out:
# KMeans(n_clusters=3)
